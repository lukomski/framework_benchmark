# %%
import pandas as pd
import seaborn as sns
import numpy as np
import json
import sys
# setting path
sys.path.append('../common')
import utils

SETUP_PATH = 'setup.json'
f = open(SETUP_PATH)
data = json.load(f)

# %%
# Clear database
import requests

clear_url = data['app']['clearUrl']
print(clear_url)
response = requests.post(clear_url)
print(response.content)
print(response.status_code)
# Out:
# http://localhost:8000/blogs/clear/
# b'{"Count of Blogs":0}'
# 200

# %%
def run_k6(app: dict, script_path: str, vus: int, dir_name):
    # !k6 run {script_path} \
        --env vus={vus} \
        --env url={app["url"]} \
        --out json={dir_name}/{app["name"]}.json \
        --out csv={dir_name}/{app["name"]}.csv

# %% [markdown]
# ## Run k6 test script

# %%
import os
import shutil
from datetime import datetime
import math 



# prepare directory structure
if not os.path.exists(data["test_result_base_dir"]):
    os.makedirs(data["test_result_base_dir"])

dt_string = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
print("date and time =", dt_string)

dir_name = f'./{data["test_result_base_dir"]}/{data["test_result_dir_prefix"]}{dt_string}'
print(dir_name)
if not os.path.exists(dir_name):
    os.makedirs(dir_name)
    
# copy script
shutil.copy(data["script_path"], dir_name)
shutil.copy(SETUP_PATH, dir_name)

out_file_name = "out-empty.txt"
out_file = open(out_file_name, "a")
out_file.write(f'\n-------------------------')
out_file.close()

vus = 2048 # initial value
beg = 1
end = None
threshold = 0
while (True):
    # run test
    run_k6(data["app"], script_path=data["script_path"], vus=vus, dir_name=dir_name)

    # load dataframe
    dir = utils.get_last_result_dir(setup_data=data)
    path = f'./{dir}/{data["app"]["name"]}.csv'
    df = pd.read_csv(path)

    # calculate metric
    incorrect_part = utils.get_incorrect_part(df)
        
    print(f'Incorrect part for vus = {vus}: {incorrect_part}\n')

    out_file = open(out_file_name, "a")
    out_file.write(f'\nvus = {vus}, beg = {beg}, end = {end}, incorrect_part = {incorrect_part}')
    out_file.close()

    if (incorrect_part > threshold):
        end = vus
        vus = math.floor((end + beg) / 2)
    else:
        beg = vus
        vus = vus * 2 if end == None else math.floor((end + beg) / 2)
    
    if end and end - beg < 2:
        break
# Out:
# date and time = 2023-11-04_17-36-38
# ./out/out_2023-11-04_17-36-38
#
#           /\      |‾‾| /‾‾/   /‾‾/
#      /\  /  \     |  |/  /   /  /
#     /  \/    \    |     (   /   ‾‾\
#    /          \   |  |\  \ |  (‾)  |
#   / __________ \  |__| \__\ \_____/ .io
#
#   execution: local
#      script: ../../grafana-k6/script.js
#      output: json (./out/out_2023-11-04_17-36-38/django.json), csv (./out/out_2023-11-04_17-36-38/django.csv)
#
#   scenarios: (100.00%) 1 scenario, 2048 max VUs, 1m0s max duration (incl. graceful stop):
#            * default: 2048 looping VUs for 30s (gracefulStop: 30s)
#
#
# Init      [=====>--------------------------------] 0327/2048 VUs initialized
# default   [--------------------------------------]
#
# Init      [==========>---------------------------] 0616/2048 VUs initialized
# default   [--------------------------------------]
#
# Init      [================>---------------------] 0968/2048 VUs initialized
# default   [--------------------------------------]
#
# Init      [======================>---------------] 1243/2048 VUs initialized
# default   [--------------------------------------]
#
# Init      [==========================>-----------] 1506/2048 VUs initialized
# default   [--------------------------------------]
#
# Init      [==================================>---] 1907/2048 VUs initialized
# default   [--------------------------------------]
#
# running (0m00.2s), 2037/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.2s/30s
#
# running (0m00.2s), 2037/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.2s/30s
#
# running (0m00.4s), 2037/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.4s/30s
#
# running (0m00.4s), 2037/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.4s/30s
#
# running (0m00.7s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.7s/30s
#
# running (0m00.7s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.7s/30s
#
# running (0m00.8s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.8s/30s
#
# running (0m00.8s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2048 VUs  00.8s/30s
#
# running (0m00.9s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  00.9s/30s
#
# running (0m01.0s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.0s/30s
#
# running (0m01.1s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.1s/30s
#
# running (0m01.2s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.2s/30s
#
# running (0m01.3s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.3s/30s
#
# running (0m01.4s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.4s/30s
#
# running (0m01.5s), 2048/2048 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.5s/30s
#
# running (0m01.6s), 2048/2048 VUs, 2 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2048 VUs  01.6s/30s
#
# running (0m01.7s), 2048/2048 VUs, 5 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  01.7s/30s
#
# running (0m01.8s), 2048/2048 VUs, 5 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  01.8s/30s
#
# running (0m01.9s), 2048/2048 VUs, 9 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  01.9s/30s
#
# running (0m02.0s), 2048/2048 VUs, 17 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  02.0s/30s
#
# running (0m02.1s), 2048/2048 VUs, 23 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  02.1s/30s
#
# running (0m02.2s), 2048/2048 VUs, 27 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  02.2s/30s
#
# running (0m02.3s), 2048/2048 VUs, 31 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2048 VUs  02.3s/30s
#
# running (0m02.4s), 2048/2048 VUs, 36 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  02.4s/30s
#
# running (0m02.5s), 2048/2048 VUs, 40 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  02.5s/30s
#
# running (0m02.6s), 2048/2048 VUs, 44 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  02.6s/30s
#
# running (0m02.7s), 2048/2048 VUs, 48 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  02.7s/30s
#
# running (0m02.8s), 2048/2048 VUs, 53 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  02.8s/30s
#
# running (0m02.9s), 2048/2048 VUs, 57 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  02.9s/30s
#
# running (0m03.0s), 2048/2048 VUs, 61 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  03.0s/30s
#
# running (0m03.1s), 2048/2048 VUs, 65 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2048 VUs  03.1s/30s
#
# running (0m03.2s), 2048/2048 VUs, 69 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.2s/30s
#
# running (0m03.3s), 2048/2048 VUs, 73 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.3s/30s
#
# running (0m03.4s), 2048/2048 VUs, 77 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.4s/30s
#
# running (0m03.5s), 2048/2048 VUs, 82 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.5s/30s
#
# running (0m03.6s), 2048/2048 VUs, 86 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.6s/30s
#
# running (0m03.7s), 2048/2048 VUs, 90 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.7s/30s
#
# running (0m03.8s), 2048/2048 VUs, 95 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.8s/30s
#
# running (0m03.9s), 2048/2048 VUs, 99 complete and 0 interrupted iterations
# default   [===>----------------------------------] 2048 VUs  03.9s/30s
#
# running (0m04.0s), 2048/2048 VUs, 103 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.0s/30s
#
# running (0m04.1s), 2048/2048 VUs, 107 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.1s/30s
#
# running (0m04.2s), 2048/2048 VUs, 111 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.2s/30s
#
# running (0m04.3s), 2048/2048 VUs, 115 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.3s/30s
#
# running (0m04.4s), 2048/2048 VUs, 120 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.4s/30s
#
# running (0m04.5s), 2048/2048 VUs, 124 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.5s/30s
#
# running (0m04.6s), 2048/2048 VUs, 128 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.6s/30s
#
# running (0m04.7s), 2048/2048 VUs, 132 complete and 0 interrupted iterations
# default   [====>---------------------------------] 2048 VUs  04.7s/30s
#
# running (0m04.8s), 2048/2048 VUs, 137 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  04.8s/30s
#
# running (0m04.9s), 2048/2048 VUs, 141 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  04.9s/30s
#
# running (0m05.0s), 2048/2048 VUs, 145 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  05.0s/30s
#
# running (0m05.1s), 2048/2048 VUs, 149 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  05.1s/30s
#
# running (0m05.2s), 2048/2048 VUs, 154 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  05.2s/30s
#
# running (0m05.3s), 2048/2048 VUs, 158 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  05.3s/30s
#
# running (0m05.4s), 2048/2048 VUs, 162 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  05.4s/30s
#
# running (0m05.5s), 2048/2048 VUs, 166 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 2048 VUs  05.5s/30s
#
# running (0m05.6s), 2048/2048 VUs, 171 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  05.6s/30s
#
# running (0m05.7s), 2048/2048 VUs, 176 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  05.7s/30s
#
# running (0m05.8s), 2048/2048 VUs, 181 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  05.8s/30s
#
# running (0m05.9s), 2048/2048 VUs, 185 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  05.9s/30s
#
# running (0m06.0s), 2048/2048 VUs, 189 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  06.0s/30s
#
# running (0m06.1s), 2048/2048 VUs, 194 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  06.1s/30s
#
# running (0m06.2s), 2048/2048 VUs, 198 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  06.2s/30s
#
# running (0m06.3s), 2048/2048 VUs, 202 complete and 0 interrupted iterations
# default   [======>-------------------------------] 2048 VUs  06.3s/30s
#
# running (0m06.4s), 2048/2048 VUs, 207 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  06.4s/30s
#
# running (0m06.5s), 2048/2048 VUs, 212 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  06.5s/30s
#
# running (0m06.6s), 2048/2048 VUs, 216 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  06.6s/30s
#
# running (0m06.7s), 2048/2048 VUs, 219 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  06.7s/30s
#
# running (0m06.8s), 2048/2048 VUs, 222 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  06.8s/30s
#
# running (0m06.9s), 2048/2048 VUs, 225 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  06.9s/30s
#
# running (0m07.0s), 2048/2048 VUs, 228 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  07.0s/30s
#
# running (0m07.1s), 2048/2048 VUs, 232 complete and 0 interrupted iterations
# default   [=======>------------------------------] 2048 VUs  07.1s/30s
#
# running (0m07.2s), 2048/2048 VUs, 235 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.2s/30s
#
# running (0m07.3s), 2048/2048 VUs, 240 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.3s/30s
#
# running (0m07.4s), 2048/2048 VUs, 244 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.4s/30s
#
# running (0m07.5s), 2048/2048 VUs, 249 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.5s/30s
#
# running (0m07.6s), 2048/2048 VUs, 253 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.6s/30s
#
# running (0m07.7s), 2048/2048 VUs, 257 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.7s/30s
#
# running (0m07.8s), 2048/2048 VUs, 261 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.8s/30s
#
# running (0m07.9s), 2048/2048 VUs, 265 complete and 0 interrupted iterations
# default   [========>-----------------------------] 2048 VUs  07.9s/30s
#
# running (0m08.0s), 2048/2048 VUs, 270 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.0s/30s
#
# running (0m08.1s), 2048/2048 VUs, 275 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.1s/30s
#
# running (0m08.2s), 2048/2048 VUs, 279 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.2s/30s
#
# running (0m08.3s), 2048/2048 VUs, 284 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.3s/30s
#
# running (0m08.4s), 2048/2048 VUs, 287 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.4s/30s
#
# running (0m08.5s), 2048/2048 VUs, 291 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.5s/30s
#
# running (0m08.6s), 2048/2048 VUs, 296 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.6s/30s
#
# running (0m08.7s), 2048/2048 VUs, 300 complete and 0 interrupted iterations
# default   [=========>----------------------------] 2048 VUs  08.7s/30s
#
# running (0m08.8s), 2048/2048 VUs, 305 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  08.8s/30s
#
# running (0m08.9s), 2048/2048 VUs, 310 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  08.9s/30s
#
# running (0m09.0s), 2048/2048 VUs, 315 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  09.0s/30s
#
# running (0m09.1s), 2048/2048 VUs, 320 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  09.1s/30s
#
# running (0m09.2s), 2048/2048 VUs, 324 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  09.2s/30s
#
# running (0m09.3s), 2048/2048 VUs, 329 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  09.3s/30s
#
# running (0m09.4s), 2048/2048 VUs, 334 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  09.4s/30s
#
# running (0m09.5s), 2048/2048 VUs, 339 complete and 0 interrupted iterations
# default   [==========>---------------------------] 2048 VUs  09.5s/30s
#
# running (0m09.6s), 2048/2048 VUs, 343 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  09.6s/30s
#
# running (0m09.7s), 2048/2048 VUs, 348 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  09.7s/30s
#
# running (0m09.8s), 2048/2048 VUs, 351 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  09.8s/30s
#
# running (0m09.9s), 2048/2048 VUs, 354 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  09.9s/30s
#
# running (0m10.0s), 2048/2048 VUs, 357 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  10.0s/30s
#
# running (0m10.1s), 2048/2048 VUs, 360 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  10.1s/30s
#
# running (0m10.2s), 2048/2048 VUs, 364 complete and 0 interrupted iterations
# default   [===========>--------------------------] 2048 VUs  10.2s/30s
#
# running (0m10.3s), 2048/2048 VUs, 368 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.3s/30s
#
# running (0m10.4s), 2048/2048 VUs, 372 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.4s/30s
#
# running (0m10.5s), 2048/2048 VUs, 377 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.5s/30s
#
# running (0m10.6s), 2048/2048 VUs, 382 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.6s/30s
#
# running (0m10.7s), 2048/2048 VUs, 387 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.7s/30s
#
# running (0m10.8s), 2048/2048 VUs, 391 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.8s/30s
#
# running (0m10.9s), 2048/2048 VUs, 396 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  10.9s/30s
#
# running (0m11.0s), 2048/2048 VUs, 401 complete and 0 interrupted iterations
# default   [============>-------------------------] 2048 VUs  11.0s/30s
#
# running (0m11.1s), 2048/2048 VUs, 406 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.1s/30s
#
# running (0m11.2s), 2048/2048 VUs, 410 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.2s/30s
#
# running (0m11.3s), 2048/2048 VUs, 415 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.3s/30s
#
# running (0m11.4s), 2048/2048 VUs, 419 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.4s/30s
#
# running (0m11.5s), 2048/2048 VUs, 424 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.5s/30s
#
# running (0m11.6s), 2048/2048 VUs, 428 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.6s/30s
#
# running (0m11.7s), 2048/2048 VUs, 432 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.7s/30s
#
# running (0m11.8s), 2048/2048 VUs, 437 complete and 0 interrupted iterations
# default   [=============>------------------------] 2048 VUs  11.8s/30s
#
# running (0m11.9s), 2048/2048 VUs, 441 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  11.9s/30s
#
# running (0m12.0s), 2048/2048 VUs, 446 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.0s/30s
#
# running (0m12.1s), 2048/2048 VUs, 451 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.1s/30s
#
# running (0m12.2s), 2048/2048 VUs, 455 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.2s/30s
#
# running (0m12.3s), 2048/2048 VUs, 460 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.3s/30s
#
# running (0m12.4s), 2048/2048 VUs, 464 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.4s/30s
#
# running (0m12.5s), 2048/2048 VUs, 469 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.5s/30s
#
# running (0m12.6s), 2048/2048 VUs, 474 complete and 0 interrupted iterations
# default   [==============>-----------------------] 2048 VUs  12.6s/30s
#
# running (0m12.7s), 2048/2048 VUs, 479 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  12.7s/30s
#
# running (0m12.8s), 2048/2048 VUs, 484 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  12.8s/30s
#
# running (0m12.9s), 2048/2048 VUs, 489 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  12.9s/30s
#
# running (0m13.0s), 2048/2048 VUs, 493 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  13.0s/30s
#
# running (0m13.1s), 2048/2048 VUs, 498 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  13.1s/30s
#
# running (0m13.2s), 2048/2048 VUs, 503 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  13.2s/30s
#
# running (0m13.3s), 2048/2048 VUs, 507 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  13.3s/30s
#
# running (0m13.4s), 2048/2048 VUs, 512 complete and 0 interrupted iterations
# default   [===============>----------------------] 2048 VUs  13.4s/30s
#
# running (0m13.5s), 2048/2048 VUs, 517 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  13.5s/30s
#
# running (0m13.6s), 2048/2048 VUs, 521 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  13.6s/30s
#
# running (0m13.7s), 2048/2048 VUs, 526 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  13.7s/30s
#
# running (0m13.8s), 2048/2048 VUs, 530 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  13.8s/30s
#
# running (0m13.9s), 2048/2048 VUs, 535 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  13.9s/30s
#
# running (0m14.0s), 2048/2048 VUs, 540 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  14.0s/30s
#
# running (0m14.1s), 2048/2048 VUs, 545 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  14.1s/30s
#
# running (0m14.2s), 2048/2048 VUs, 550 complete and 0 interrupted iterations
# default   [================>---------------------] 2048 VUs  14.2s/30s
#
# running (0m14.3s), 2048/2048 VUs, 554 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.3s/30s
#
# running (0m14.4s), 2048/2048 VUs, 559 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.4s/30s
#
# running (0m14.5s), 2048/2048 VUs, 564 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.5s/30s
#
# running (0m14.6s), 2048/2048 VUs, 569 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.6s/30s
#
# running (0m14.7s), 2048/2048 VUs, 573 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.7s/30s
#
# running (0m14.8s), 2048/2048 VUs, 578 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.8s/30s
#
# running (0m14.9s), 2048/2048 VUs, 582 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  14.9s/30s
#
# running (0m15.0s), 2048/2048 VUs, 586 complete and 0 interrupted iterations
# default   [=================>--------------------] 2048 VUs  15.0s/30s
#
# running (0m15.1s), 2048/2048 VUs, 591 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.1s/30s
#
# running (0m15.2s), 2048/2048 VUs, 596 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.2s/30s
#
# running (0m15.3s), 2048/2048 VUs, 600 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.3s/30s
#
# running (0m15.4s), 2048/2048 VUs, 605 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.4s/30s
#
# running (0m15.5s), 2048/2048 VUs, 609 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.5s/30s
#
# running (0m15.6s), 2048/2048 VUs, 614 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.6s/30s
#
# running (0m15.7s), 2048/2048 VUs, 619 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.7s/30s
#
# running (0m15.8s), 2048/2048 VUs, 624 complete and 0 interrupted iterations
# default   [==================>-------------------] 2048 VUs  15.8s/30s
#
# running (0m15.9s), 2048/2048 VUs, 628 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  15.9s/30s
#
# running (0m16.0s), 2048/2048 VUs, 633 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.0s/30s
#
# running (0m16.1s), 2048/2048 VUs, 637 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.1s/30s
#
# running (0m16.2s), 2048/2048 VUs, 641 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.2s/30s
#
# running (0m16.3s), 2048/2048 VUs, 646 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.3s/30s
#
# running (0m16.4s), 2048/2048 VUs, 650 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.4s/30s
#
# running (0m16.5s), 2048/2048 VUs, 655 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.5s/30s
#
# running (0m16.6s), 2048/2048 VUs, 660 complete and 0 interrupted iterations
# default   [===================>------------------] 2048 VUs  16.6s/30s
#
# running (0m16.7s), 2048/2048 VUs, 665 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  16.7s/30s
#
# running (0m16.8s), 2048/2048 VUs, 670 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  16.8s/30s
#
# running (0m16.9s), 2048/2048 VUs, 674 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  16.9s/30s
#
# running (0m17.0s), 2048/2048 VUs, 679 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  17.0s/30s
#
# running (0m17.1s), 2048/2048 VUs, 684 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  17.1s/30s
#
# running (0m17.2s), 2048/2048 VUs, 688 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  17.2s/30s
#
# running (0m17.3s), 2048/2048 VUs, 693 complete and 0 interrupted iterations
# default   [====================>-----------------] 2048 VUs  17.3s/30s
#
# running (0m17.4s), 2048/2048 VUs, 698 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  17.4s/30s
#
# running (0m17.5s), 2048/2048 VUs, 703 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  17.5s/30s
#
# running (0m17.6s), 2048/2048 VUs, 707 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  17.6s/30s
#
# running (0m17.7s), 2048/2048 VUs, 712 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  17.7s/30s
#
# running (0m17.8s), 2048/2048 VUs, 717 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  17.8s/30s
#
# running (0m17.9s), 2048/2048 VUs, 722 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  17.9s/30s
#
# running (0m18.0s), 2048/2048 VUs, 726 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  18.0s/30s
#
# running (0m18.1s), 2048/2048 VUs, 731 complete and 0 interrupted iterations
# default   [=====================>----------------] 2048 VUs  18.1s/30s
#
# running (0m18.2s), 2048/2048 VUs, 736 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.2s/30s
#
# running (0m18.3s), 2048/2048 VUs, 741 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.3s/30s
#
# running (0m18.4s), 2048/2048 VUs, 746 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.4s/30s
#
# running (0m18.5s), 2048/2048 VUs, 750 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.5s/30s
#
# running (0m18.6s), 2048/2048 VUs, 755 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.6s/30s
#
# running (0m18.7s), 2048/2048 VUs, 760 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.7s/30s
#
# running (0m18.8s), 2048/2048 VUs, 764 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.8s/30s
#
# running (0m18.9s), 2048/2048 VUs, 769 complete and 0 interrupted iterations
# default   [======================>---------------] 2048 VUs  18.9s/30s
#
# running (0m19.0s), 2048/2048 VUs, 774 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.0s/30s
#
# running (0m19.1s), 2048/2048 VUs, 778 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.1s/30s
#
# running (0m19.2s), 2048/2048 VUs, 782 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.2s/30s
#
# running (0m19.3s), 2048/2048 VUs, 785 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.3s/30s
#
# running (0m19.4s), 2048/2048 VUs, 788 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.4s/30s
#
# running (0m19.5s), 2048/2048 VUs, 792 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.5s/30s
#
# running (0m19.6s), 2048/2048 VUs, 796 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.6s/30s
#
# running (0m19.7s), 2048/2048 VUs, 800 complete and 0 interrupted iterations
# default   [=======================>--------------] 2048 VUs  19.7s/30s
#
# running (0m19.8s), 2048/2048 VUs, 805 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  19.8s/30s
#
# running (0m19.9s), 2048/2048 VUs, 810 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  19.9s/30s
#
# running (0m20.0s), 2048/2048 VUs, 814 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  20.0s/30s
#
# running (0m20.1s), 2048/2048 VUs, 819 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  20.1s/30s
#
# running (0m20.2s), 2048/2048 VUs, 824 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  20.2s/30s
#
# running (0m20.3s), 2048/2048 VUs, 829 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  20.3s/30s
#
# running (0m20.4s), 2048/2048 VUs, 833 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  20.4s/30s
#
# running (0m20.5s), 2048/2048 VUs, 838 complete and 0 interrupted iterations
# default   [========================>-------------] 2048 VUs  20.5s/30s
#
# running (0m20.6s), 2048/2048 VUs, 842 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  20.6s/30s
#
# running (0m20.7s), 2048/2048 VUs, 846 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  20.7s/30s
#
# running (0m20.8s), 2048/2048 VUs, 851 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  20.8s/30s
#
# running (0m20.9s), 2048/2048 VUs, 856 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  20.9s/30s
#
# running (0m21.0s), 2048/2048 VUs, 860 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  21.0s/30s
#
# running (0m21.1s), 2048/2048 VUs, 865 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  21.1s/30s
#
# running (0m21.2s), 2048/2048 VUs, 870 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  21.2s/30s
#
# running (0m21.3s), 2048/2048 VUs, 875 complete and 0 interrupted iterations
# default   [=========================>------------] 2048 VUs  21.3s/30s
#
# running (0m21.4s), 2048/2048 VUs, 880 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  21.4s/30s
#
# running (0m21.5s), 2048/2048 VUs, 885 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  21.5s/30s
#
# running (0m21.6s), 2048/2048 VUs, 890 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  21.6s/30s
#
# running (0m21.7s), 2048/2048 VUs, 894 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  21.7s/30s
#
# running (0m21.8s), 2048/2048 VUs, 899 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  21.8s/30s
#
# running (0m21.9s), 2048/2048 VUs, 904 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  21.9s/30s
#
# running (0m22.0s), 2048/2048 VUs, 909 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  22.0s/30s
#
# running (0m22.1s), 2048/2048 VUs, 913 complete and 0 interrupted iterations
# default   [==========================>-----------] 2048 VUs  22.1s/30s
#
# running (0m22.2s), 2048/2048 VUs, 918 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.2s/30s
#
# running (0m22.3s), 2048/2048 VUs, 923 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.3s/30s
#
# running (0m22.4s), 2048/2048 VUs, 928 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.4s/30s
#
# running (0m22.5s), 2048/2048 VUs, 932 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.5s/30s
#
# running (0m22.6s), 2048/2048 VUs, 937 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.6s/30s
#
# running (0m22.7s), 2048/2048 VUs, 941 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.7s/30s
#
# running (0m22.8s), 2048/2048 VUs, 944 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.8s/30s
#
# running (0m22.9s), 2048/2048 VUs, 947 complete and 0 interrupted iterations
# default   [===========================>----------] 2048 VUs  22.9s/30s
#
# running (0m23.0s), 2048/2048 VUs, 950 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.0s/30s
#
# running (0m23.1s), 2048/2048 VUs, 954 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.1s/30s
#
# running (0m23.2s), 2048/2048 VUs, 959 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.2s/30s
#
# running (0m23.3s), 2048/2048 VUs, 962 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.3s/30s
#
# running (0m23.4s), 2048/2048 VUs, 967 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.4s/30s
#
# running (0m23.5s), 2048/2048 VUs, 971 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.5s/30s
#
# running (0m23.6s), 2048/2048 VUs, 976 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.6s/30s
#
# running (0m23.7s), 2048/2048 VUs, 981 complete and 0 interrupted iterations
# default   [============================>---------] 2048 VUs  23.7s/30s
#
# running (0m23.8s), 2048/2048 VUs, 986 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  23.8s/30s
#
# running (0m23.9s), 2048/2048 VUs, 991 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  23.9s/30s
#
# running (0m24.0s), 2048/2048 VUs, 995 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  24.0s/30s
#
# running (0m24.1s), 2048/2048 VUs, 1000 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  24.1s/30s
#
# running (0m24.2s), 2048/2048 VUs, 1005 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  24.2s/30s
#
# running (0m24.3s), 2048/2048 VUs, 1010 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  24.3s/30s
#
# running (0m24.4s), 2048/2048 VUs, 1015 complete and 0 interrupted iterations
# default   [=============================>--------] 2048 VUs  24.4s/30s
#
# running (0m24.5s), 2048/2048 VUs, 1019 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  24.5s/30s
#
# running (0m24.6s), 2048/2048 VUs, 1024 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  24.6s/30s
#
# running (0m24.7s), 2048/2048 VUs, 1029 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  24.7s/30s
#
# running (0m24.8s), 2048/2048 VUs, 1034 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  24.8s/30s
#
# running (0m24.9s), 2048/2048 VUs, 1038 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  24.9s/30s
#
# running (0m25.0s), 2048/2048 VUs, 1043 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  25.0s/30s
#
# running (0m25.1s), 2048/2048 VUs, 1047 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  25.1s/30s
#
# running (0m25.2s), 2048/2048 VUs, 1052 complete and 0 interrupted iterations
# default   [==============================>-------] 2048 VUs  25.2s/30s
#
# running (0m25.3s), 2048/2048 VUs, 1056 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.3s/30s
#
# running (0m25.4s), 2048/2048 VUs, 1059 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.4s/30s
#
# running (0m25.5s), 2048/2048 VUs, 1062 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.5s/30s
#
# running (0m25.6s), 2048/2048 VUs, 1066 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.6s/30s
#
# running (0m25.7s), 2048/2048 VUs, 1070 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.7s/30s
#
# running (0m25.8s), 2048/2048 VUs, 1075 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.8s/30s
#
# running (0m25.9s), 2048/2048 VUs, 1079 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  25.9s/30s
#
# running (0m26.0s), 2048/2048 VUs, 1084 complete and 0 interrupted iterations
# default   [===============================>------] 2048 VUs  26.0s/30s
#
# running (0m26.1s), 2048/2048 VUs, 1089 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.1s/30s
#
# running (0m26.2s), 2048/2048 VUs, 1093 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.2s/30s
#
# running (0m26.3s), 2048/2048 VUs, 1098 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.3s/30s
#
# running (0m26.4s), 2048/2048 VUs, 1103 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.4s/30s
#
# running (0m26.5s), 2048/2048 VUs, 1108 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.5s/30s
#
# running (0m26.6s), 2048/2048 VUs, 1112 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.6s/30s
#
# running (0m26.7s), 2048/2048 VUs, 1116 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.7s/30s
#
# running (0m26.8s), 2048/2048 VUs, 1120 complete and 0 interrupted iterations
# default   [================================>-----] 2048 VUs  26.8s/30s
#
# running (0m26.9s), 2048/2048 VUs, 1125 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  26.9s/30s
#
# running (0m27.0s), 2048/2048 VUs, 1130 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.0s/30s
#
# running (0m27.1s), 2048/2048 VUs, 1134 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.1s/30s
#
# running (0m27.2s), 2048/2048 VUs, 1139 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.2s/30s
#
# running (0m27.3s), 2048/2048 VUs, 1144 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.3s/30s
#
# running (0m27.4s), 2048/2048 VUs, 1149 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.4s/30s
#
# running (0m27.5s), 2048/2048 VUs, 1153 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.5s/30s
#
# running (0m27.6s), 2048/2048 VUs, 1158 complete and 0 interrupted iterations
# default   [=================================>----] 2048 VUs  27.6s/30s
#
# running (0m27.7s), 2048/2048 VUs, 1163 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  27.7s/30s
#
# running (0m27.8s), 2048/2048 VUs, 1168 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  27.8s/30s
#
# running (0m27.9s), 2048/2048 VUs, 1172 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  27.9s/30s
#
# running (0m28.0s), 2048/2048 VUs, 1177 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  28.0s/30s
#
# running (0m28.1s), 2048/2048 VUs, 1182 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  28.1s/30s
#
# running (0m28.2s), 2048/2048 VUs, 1187 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  28.2s/30s
#
# running (0m28.3s), 2048/2048 VUs, 1191 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  28.3s/30s
#
# running (0m28.4s), 2048/2048 VUs, 1196 complete and 0 interrupted iterations
# default   [==================================>---] 2048 VUs  28.4s/30s
#
# running (0m28.5s), 2048/2048 VUs, 1201 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  28.5s/30s
#
# running (0m28.6s), 2048/2048 VUs, 1205 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  28.6s/30s
#
# running (0m28.7s), 2048/2048 VUs, 1210 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  28.7s/30s
#
# running (0m28.8s), 2048/2048 VUs, 1215 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  28.8s/30s
#
# running (0m28.9s), 2048/2048 VUs, 1220 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  28.9s/30s
#
# running (0m29.0s), 2048/2048 VUs, 1225 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  29.0s/30s
#
# running (0m29.1s), 2048/2048 VUs, 1229 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  29.1s/30s
#
# running (0m29.2s), 2048/2048 VUs, 1234 complete and 0 interrupted iterations
# default   [===================================>--] 2048 VUs  29.2s/30s
#
# running (0m29.3s), 2048/2048 VUs, 1239 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.3s/30s
#
# running (0m29.4s), 2048/2048 VUs, 1243 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.4s/30s
#
# running (0m29.5s), 2048/2048 VUs, 1247 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.5s/30s
#
# running (0m29.6s), 2048/2048 VUs, 1251 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.6s/30s
#
# running (0m29.7s), 2048/2048 VUs, 1255 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.7s/30s
#
# running (0m29.8s), 2048/2048 VUs, 1260 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.8s/30s
#
# running (0m29.9s), 2048/2048 VUs, 1265 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  29.9s/30s
#
# running (0m30.0s), 2048/2048 VUs, 1270 complete and 0 interrupted iterations
# default   [====================================>-] 2048 VUs  30.0s/30s
#
# running (0m30.1s), 2044/2048 VUs, 1275 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.2s), 2040/2048 VUs, 1279 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.3s), 2035/2048 VUs, 1284 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.4s), 2030/2048 VUs, 1289 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.5s), 2026/2048 VUs, 1293 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.6s), 2022/2048 VUs, 1297 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.7s), 2018/2048 VUs, 1301 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.8s), 2015/2048 VUs, 1304 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m30.9s), 2011/2048 VUs, 1308 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.0s), 2008/2048 VUs, 1311 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.1s), 2003/2048 VUs, 1316 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.2s), 1998/2048 VUs, 1321 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.3s), 1994/2048 VUs, 1325 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.4s), 1989/2048 VUs, 1330 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.5s), 1984/2048 VUs, 1335 complete and 0 interrupted iterations
# default ↓ [======================================] 2048 VUs  30s
#
# running (0m31.6s), 1979/2048 VUs, 1340 complete and 0 interrupted iterations
# ...
#
# running (0m50.6s), 2259/3159 VUs, 933 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m50.7s), 2257/3159 VUs, 935 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m50.8s), 2253/3159 VUs, 939 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m50.9s), 2248/3159 VUs, 944 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.0s), 2243/3159 VUs, 949 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.1s), 2239/3159 VUs, 953 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.2s), 2234/3159 VUs, 958 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.3s), 2230/3159 VUs, 962 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.4s), 2225/3159 VUs, 967 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.5s), 2220/3159 VUs, 972 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.6s), 2216/3159 VUs, 976 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.7s), 2212/3159 VUs, 980 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.8s), 2208/3159 VUs, 984 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m51.9s), 2203/3159 VUs, 989 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.0s), 2199/3159 VUs, 993 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.1s), 2194/3159 VUs, 998 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.2s), 2189/3159 VUs, 1003 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.3s), 2185/3159 VUs, 1007 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.4s), 2180/3159 VUs, 1012 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.5s), 2176/3159 VUs, 1016 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.6s), 2171/3159 VUs, 1021 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.7s), 2167/3159 VUs, 1025 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.8s), 2163/3159 VUs, 1029 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m52.9s), 2158/3159 VUs, 1034 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.0s), 2154/3159 VUs, 1038 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.1s), 2149/3159 VUs, 1043 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.2s), 2144/3159 VUs, 1048 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.3s), 2140/3159 VUs, 1052 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.4s), 2135/3159 VUs, 1057 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.5s), 2131/3159 VUs, 1061 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.6s), 2127/3159 VUs, 1065 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.7s), 2122/3159 VUs, 1070 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.8s), 2118/3159 VUs, 1074 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m53.9s), 2115/3159 VUs, 1077 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.0s), 2110/3159 VUs, 1082 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.1s), 2106/3159 VUs, 1086 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.2s), 2102/3159 VUs, 1090 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.3s), 2097/3159 VUs, 1095 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.4s), 2094/3159 VUs, 1098 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.5s), 2089/3159 VUs, 1103 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.6s), 2085/3159 VUs, 1107 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.7s), 2081/3159 VUs, 1111 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.8s), 2076/3159 VUs, 1116 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m54.9s), 2073/3159 VUs, 1119 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.0s), 2070/3159 VUs, 1122 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.1s), 2067/3159 VUs, 1125 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.2s), 2064/3159 VUs, 1128 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.3s), 2060/3159 VUs, 1132 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.4s), 2056/3159 VUs, 1136 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.5s), 2052/3159 VUs, 1140 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.6s), 2048/3159 VUs, 1144 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.7s), 2044/3159 VUs, 1148 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.8s), 2039/3159 VUs, 1153 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m55.9s), 2034/3159 VUs, 1158 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.0s), 2031/3159 VUs, 1161 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.1s), 2027/3159 VUs, 1165 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.2s), 2024/3159 VUs, 1168 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.3s), 2019/3159 VUs, 1173 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.4s), 2014/3159 VUs, 1178 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.5s), 2009/3159 VUs, 1183 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.6s), 2005/3159 VUs, 1187 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.7s), 2000/3159 VUs, 1192 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.8s), 1995/3159 VUs, 1197 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m56.9s), 1990/3159 VUs, 1202 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.0s), 1986/3159 VUs, 1206 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.1s), 1982/3159 VUs, 1210 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.2s), 1977/3159 VUs, 1215 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.3s), 1972/3159 VUs, 1220 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.4s), 1968/3159 VUs, 1224 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.5s), 1963/3159 VUs, 1229 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.6s), 1958/3159 VUs, 1234 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.7s), 1954/3159 VUs, 1238 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.8s), 1949/3159 VUs, 1243 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m57.9s), 1945/3159 VUs, 1247 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.0s), 1941/3159 VUs, 1251 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.1s), 1938/3159 VUs, 1254 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.2s), 1934/3159 VUs, 1258 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.3s), 1930/3159 VUs, 1262 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.4s), 1926/3159 VUs, 1266 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.5s), 1923/3159 VUs, 1269 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.6s), 1919/3159 VUs, 1273 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.7s), 1914/3159 VUs, 1278 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.8s), 1909/3159 VUs, 1283 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m58.9s), 1905/3159 VUs, 1287 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.0s), 1900/3159 VUs, 1292 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.1s), 1895/3159 VUs, 1297 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.2s), 1891/3159 VUs, 1301 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.3s), 1887/3159 VUs, 1305 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.4s), 1883/3159 VUs, 1309 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.5s), 1878/3159 VUs, 1314 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.6s), 1874/3159 VUs, 1318 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.7s), 1869/3159 VUs, 1323 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.8s), 1864/3159 VUs, 1328 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (0m59.9s), 1860/3159 VUs, 1332 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (1m00.0s), 1856/3159 VUs, 1337 complete and 0 interrupted iterations
# default ↓ [======================================] 3159 VUs  30s
#
# running (1m00.1s), 0989/3159 VUs, 1337 complete and 868 interrupted iterations
# default ✓ [======================================] 3159 VUs  30s
#
# running (1m00.3s), 0176/3159 VUs, 1337 complete and 1680 interrupted iterations
# default ✓ [======================================] 3159 VUs  30s
#
# running (1m00.3s), 0003/3159 VUs, 1337 complete and 1852 interrupted iterations
# default ✓ [======================================] 3159 VUs  30s
#
# running (1m00.3s), 0000/3159 VUs, 1337 complete and 1855 interrupted iterations
# default ✓ [======================================] 3159 VUs  30s
#
#      data_received..................: 466 kB 7.7 kB/s
#      data_sent......................: 291 kB 4.8 kB/s
#      http_req_blocked...............: avg=377.07ms min=554.79µs med=331.01ms max=1.38s   p(90)=586.01ms p(95)=818.55ms
#      http_req_connecting............: avg=363.88ms min=425.19µs med=328.48ms max=1.36s   p(90)=566.45ms p(95)=725.6ms
#      http_req_duration..............: avg=43.3s    min=28s      med=43.44s   max=59.1s   p(90)=55.88s   p(95)=57.04s
#        { expected_response:true }...: avg=43.3s    min=28s      med=43.44s   max=59.1s   p(90)=55.88s   p(95)=57.04s
#      http_req_failed................: 0.00%  ✓ 0         ✗ 1381
#      http_req_receiving.............: avg=230.97µs min=139.71µs med=201.22µs max=3.79ms  p(90)=297.78µs p(95)=391.94µs
#      http_req_sending...............: avg=88.95ms  min=64.09µs  med=46.1ms   max=781.9ms p(90)=256.11ms p(95)=318.82ms
#      http_req_tls_handshaking.......: avg=0s       min=0s       med=0s       max=0s      p(90)=0s       p(95)=0s
#      http_req_waiting...............: avg=43.22s   min=28s      med=43.39s   max=59.05s  p(90)=55.87s   p(95)=56.88s
#      http_reqs......................: 1381   22.895944/s
#      iteration_duration.............: avg=44.17s   min=29.19s   med=44.23s   max=59.9s   p(90)=56.09s   p(95)=57.88s
#      iterations.....................: 1337   22.166457/s
#      vus............................: 412    min=0       max=3159
#      vus_max........................: 3159   min=1604    max=3159
#
#
# running (1m00.3s), 0000/3159 VUs, 1337 complete and 1855 interrupted iterations
# default ✓ [======================================] 3159 VUs  30s
#
# running (1m00.3s), 0000/3159 VUs, 1337 complete and 1855 interrupted iterations
# default ✓ [======================================] 3159 VUs  30s
# Incorrect part for vus = 3159: 0.0

# %% [markdown]
# ## Smoke Processing data

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import sys
# setting path
sys.path.append('../common')
import utils


dir = utils.get_last_result_dir(setup_data=data)
print(dir)
path = f'.{data["test_result_base_dir"]}/{dir}/django.json'
print(path)
df = pd.read_csv(f'{dir}/django.csv')
# Out:
# out/out_2023-11-04_17-36-38
# .out/out/out_2023-11-04_17-36-38/django.json

# %%
path = f'./{dir}/{data["app"]["name"]}.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   metric_name   timestamp  metric_value  check  error  error_code  \
# 0         vus  1699116623           0.0    NaN    NaN         NaN
# 1     vus_max  1699116623        1604.0    NaN    NaN         NaN
# 2         vus  1699116624        1473.0    NaN    NaN         NaN
# 3     vus_max  1699116624        3159.0    NaN    NaN         NaN
# 4         vus  1699116625        3159.0    NaN    NaN         NaN
#
#   expected_response  group method name proto scenario  service  status  \
# 0               NaN    NaN    NaN  NaN   NaN      NaN      NaN     NaN
# 1               NaN    NaN    NaN  NaN   NaN      NaN      NaN     NaN
# 2               NaN    NaN    NaN  NaN   NaN      NaN      NaN     NaN
# 3               NaN    NaN    NaN  NaN   NaN      NaN      NaN     NaN
# 4               NaN    NaN    NaN  NaN   NaN      NaN      NaN     NaN
#
#    subproto  tls_version  url  extra_tags  metadata
# 0       NaN          NaN  NaN         NaN       NaN
# 1       NaN          NaN  NaN         NaN       NaN
# 2       NaN          NaN  NaN         NaN       NaN
# 3       NaN          NaN  NaN         NaN       NaN
# 4       NaN          NaN  NaN         NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21611 entries, 0 to 21610
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   metric_name        21611 non-null  object
#  1   timestamp          21611 non-null  int64
#  2   metric_value       21611 non-null  float64
#  3   check              0 non-null      float64
#  4   error              0 non-null      float64
#  5   error_code         0 non-null      float64
#  6   expected_response  12429 non-null  object
#  7   group              0 non-null      float64
#  8   method             12429 non-null  object
#  9   name               12429 non-null  object
#  10  proto              12429 non-null  object
#  11  scenario           21487 non-null  object
#  12  service            0 non-null      float64
#  13  status             12429 non-null  float64
#  14  subproto           0 non-null      float64
#  15  tls_version        0 non-null      float64
#  16  url                12429 non-null  object
#  17  extra_tags         0 non-null      float64
#  18  metadata           0 non-null      float64
# dtypes: float64(11), int64(1), object(7)
# memory usage: 3.1+ MB

# %%
df['metric_name'].unique()
# Out:
# array(['vus', 'vus_max', 'http_reqs', 'http_req_duration',
#        'http_req_blocked', 'http_req_connecting',
#        'http_req_tls_handshaking', 'http_req_sending', 'http_req_waiting',
#        'http_req_receiving', 'http_req_failed', 'data_sent',
#        'data_received', 'iteration_duration', 'iterations'], dtype=object)

# %%
chart = sns.countplot(data=df, x='metric_name')
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
chart.bar_label(chart.containers[0])
# Out:
# [Text(0, 0, '62'),
#  Text(0, 0, '62'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '1381'),
#  Text(0, 0, '3192'),
#  Text(0, 0, '3192'),
#  Text(0, 0, '1337'),
#  Text(0, 0, '1337')]

# %%
df.shape
# Out:
# (21611, 19)

# %%
df_1 = df.loc[(df['metric_name'] == 'http_req_duration')]
df_1.shape
# Out:
# (1381, 19)

# %%
df_1.head()
# Out:
#           metric_name   timestamp  metric_value  check  error  error_code  \
# 61  http_req_duration  1699116652  28258.753110    NaN    NaN         NaN
# 70  http_req_duration  1699116652  28282.775004    NaN    NaN         NaN
# 79  http_req_duration  1699116652  28205.278620    NaN    NaN         NaN
# 88  http_req_duration  1699116652  28004.738652    NaN    NaN         NaN
# 97  http_req_duration  1699116652  28188.790101    NaN    NaN         NaN
#
#    expected_response  group method                               name  \
# 61              True    NaN    GET  http://localhost:8000/collisions/
# 70              True    NaN    GET  http://localhost:8000/collisions/
# 79              True    NaN    GET  http://localhost:8000/collisions/
# 88              True    NaN    GET  http://localhost:8000/collisions/
# 97              True    NaN    GET  http://localhost:8000/collisions/
#
#        proto scenario  service  status  subproto  tls_version  \
# 61  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 70  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 79  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 88  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 97  HTTP/1.1  default      NaN   200.0       NaN          NaN
#
#                                   url  extra_tags  metadata
# 61  http://localhost:8000/collisions/         NaN       NaN
# 70  http://localhost:8000/collisions/         NaN       NaN
# 79  http://localhost:8000/collisions/         NaN       NaN
# 88  http://localhost:8000/collisions/         NaN       NaN
# 97  http://localhost:8000/collisions/         NaN       NaN
