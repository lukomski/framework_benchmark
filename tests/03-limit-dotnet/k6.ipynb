# %%
import pandas as pd
import seaborn as sns
import numpy as np
import json
import sys
# setting path
sys.path.append('../common')
import utils

SETUP_PATH = 'setup.json'
f = open(SETUP_PATH)
data = json.load(f)

# %%
def run_k6(app: dict, script_path: str, vus: int, dir_name):
    # !k6 run {script_path} \
        --env vus={vus} \
        --env url={app["url"]} \
        --out json={dir_name}/{app["name"]}.json \
        --out csv={dir_name}/{app["name"]}.csv

# %% [markdown]
# ## Run k6 test script

# %%
import os
import shutil
from datetime import datetime
import math 



# prepare directory structure
if not os.path.exists(data["test_result_base_dir"]):
    os.makedirs(data["test_result_base_dir"])

dt_string = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
print("date and time =", dt_string)

dir_name = f'./{data["test_result_base_dir"]}/{data["test_result_dir_prefix"]}{dt_string}'
print(dir_name)
if not os.path.exists(dir_name):
    os.makedirs(dir_name)
    
# copy script
shutil.copy(data["script_path"], dir_name)
shutil.copy(SETUP_PATH, dir_name)

out_file = open("out.txt", "a")
out_file.write(f'\n-------------------------')
out_file.close()

vus = 1 # initial value
beg = 1
end = None
threshold = 0
while (True):
    # run test
    run_k6(data["app"], script_path=data["script_path"], vus=vus, dir_name=dir_name)

    # load dataframe
    dir = utils.get_last_result_dir(setup_data=data)
    path = f'./{dir}/{data["app"]["name"]}.csv'
    df = pd.read_csv(path)

    # calculate metric
    incorrect_part = utils.get_incorrect_part(df)
        
    print(f'Incorrect part for vus = {vus}: {incorrect_part}\n')

    out_file = open("out.txt", "a")
    out_file.write(f'\nvus = {vus}, beg = {beg}, end = {end}, incorrect_part = {incorrect_part}')
    out_file.close()

    if (incorrect_part > threshold):
        end = vus
        vus = math.floor((end + beg) / 2)
    else:
        beg = vus
        vus = vus * 2 if end == None else math.floor((end + beg) / 2)
    
    if end and end - beg < 2:
        break
# Out:
# date and time = 2023-10-26_22-16-40
# ./out/out_2023-10-26_22-16-40
#
#           /\      |‾‾| /‾‾/   /‾‾/
#      /\  /  \     |  |/  /   /  /
#     /  \/    \    |     (   /   ‾‾\
#    /          \   |  |\  \ |  (‾)  |
#   / __________ \  |__| \__\ \_____/ .io
#
#   execution: local
#      script: ../../grafana-k6/script.js
#      output: json (./out/out_2023-10-26_22-16-40/dotnet.json), csv (./out/out_2023-10-26_22-16-40/dotnet.csv)
#
#   scenarios: (100.00%) 1 scenario, 1 max VUs, 1m0s max duration (incl. graceful stop):
#            * default: 1 looping VUs for 30s (gracefulStop: 30s)
#
#
# running (0m00.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.1s/30s
#
# running (0m00.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.2s/30s
#
# running (0m00.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.3s/30s
#
# running (0m00.4s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.4s/30s
#
# running (0m00.5s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.5s/30s
#
# running (0m00.6s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.6s/30s
#
# running (0m00.7s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 1 VUs  00.7s/30s
#
# running (0m00.8s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  00.8s/30s
#
# running (0m00.9s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  00.9s/30s
#
# running (0m01.0s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  01.0s/30s
#
# running (0m01.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  01.1s/30s
#
# running (0m01.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  01.2s/30s
#
# running (0m01.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  01.3s/30s
#
# running (0m01.4s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  01.4s/30s
#
# running (0m01.5s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 1 VUs  01.5s/30s
#
# running (0m01.6s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  01.6s/30s
#
# running (0m01.7s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  01.7s/30s
#
# running (0m01.8s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  01.8s/30s
#
# running (0m01.9s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  01.9s/30s
#
# running (0m02.0s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  02.0s/30s
#
# running (0m02.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  02.1s/30s
#
# running (0m02.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  02.2s/30s
#
# running (0m02.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=>------------------------------------] 1 VUs  02.3s/30s
#
# running (0m02.4s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  02.4s/30s
#
# running (0m02.5s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  02.5s/30s
#
# running (0m02.6s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  02.6s/30s
#
# running (0m02.7s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  02.7s/30s
#
# running (0m02.8s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  02.8s/30s
#
# running (0m02.9s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  02.9s/30s
#
# running (0m03.0s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  03.0s/30s
#
# running (0m03.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 1 VUs  03.1s/30s
#
# running (0m03.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.2s/30s
#
# running (0m03.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.3s/30s
#
# running (0m03.4s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.4s/30s
#
# running (0m03.5s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.5s/30s
#
# running (0m03.6s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.6s/30s
#
# running (0m03.7s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.7s/30s
#
# running (0m03.8s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.8s/30s
#
# running (0m03.9s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [===>----------------------------------] 1 VUs  03.9s/30s
#
# running (0m04.0s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.0s/30s
#
# running (0m04.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.1s/30s
#
# running (0m04.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.2s/30s
#
# running (0m04.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.3s/30s
#
# running (0m04.4s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.4s/30s
#
# running (0m04.5s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.5s/30s
#
# running (0m04.6s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.6s/30s
#
# running (0m04.7s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [====>---------------------------------] 1 VUs  04.7s/30s
#
# running (0m04.8s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  04.8s/30s
#
# running (0m04.9s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  04.9s/30s
#
# running (0m05.0s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  05.0s/30s
#
# running (0m05.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  05.1s/30s
#
# running (0m05.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  05.2s/30s
#
# running (0m05.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  05.3s/30s
#
# running (0m05.4s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  05.4s/30s
#
# running (0m05.5s), 1/1 VUs, 0 complete and 0 interrupted iterations
# default   [=====>--------------------------------] 1 VUs  05.5s/30s
#
# running (0m05.6s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  05.6s/30s
#
# running (0m05.7s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  05.7s/30s
#
# running (0m05.8s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  05.8s/30s
#
# running (0m05.9s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  05.9s/30s
#
# running (0m06.0s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  06.0s/30s
#
# running (0m06.1s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  06.1s/30s
#
# running (0m06.2s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  06.2s/30s
#
# running (0m06.3s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [======>-------------------------------] 1 VUs  06.3s/30s
#
# running (0m06.4s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  06.4s/30s
#
# running (0m06.5s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  06.5s/30s
#
# running (0m06.6s), 1/1 VUs, 1 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  06.6s/30s
#
# running (0m06.7s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  06.7s/30s
#
# running (0m06.8s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  06.8s/30s
#
# running (0m06.9s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  06.9s/30s
#
# running (0m07.0s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  07.0s/30s
#
# running (0m07.1s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [=======>------------------------------] 1 VUs  07.1s/30s
#
# running (0m07.2s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.2s/30s
#
# running (0m07.3s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.3s/30s
#
# running (0m07.4s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.4s/30s
#
# running (0m07.5s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.5s/30s
#
# running (0m07.6s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.6s/30s
#
# running (0m07.7s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.7s/30s
#
# running (0m07.8s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [========>-----------------------------] 1 VUs  07.8s/30s
#
# running (0m07.9s), 1/1 VUs, 2 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  07.9s/30s
#
# running (0m08.0s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.0s/30s
#
# running (0m08.1s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.1s/30s
#
# running (0m08.2s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.2s/30s
#
# running (0m08.3s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.3s/30s
#
# running (0m08.4s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.4s/30s
#
# running (0m08.5s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.5s/30s
#
# running (0m08.6s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [=========>----------------------------] 1 VUs  08.6s/30s
#
# running (0m08.7s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  08.7s/30s
#
# running (0m08.8s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  08.8s/30s
#
# running (0m08.9s), 1/1 VUs, 3 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  08.9s/30s
#
# running (0m09.0s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  09.0s/30s
#
# running (0m09.1s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  09.1s/30s
#
# running (0m09.2s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  09.2s/30s
#
# running (0m09.3s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  09.3s/30s
#
# running (0m09.4s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [==========>---------------------------] 1 VUs  09.4s/30s
#
# running (0m09.5s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  09.5s/30s
#
# running (0m09.6s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  09.6s/30s
#
# running (0m09.7s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  09.7s/30s
#
# running (0m09.8s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  09.8s/30s
#
# running (0m09.9s), 1/1 VUs, 4 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  09.9s/30s
#
# running (0m10.0s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  10.0s/30s
#
# running (0m10.1s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  10.1s/30s
#
# running (0m10.2s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [===========>--------------------------] 1 VUs  10.2s/30s
#
# running (0m10.3s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.3s/30s
#
# running (0m10.4s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.4s/30s
#
# running (0m10.5s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.5s/30s
#
# running (0m10.6s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.6s/30s
#
# running (0m10.7s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.7s/30s
#
# running (0m10.8s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.8s/30s
#
# running (0m10.9s), 1/1 VUs, 5 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  10.9s/30s
#
# running (0m11.0s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [============>-------------------------] 1 VUs  11.0s/30s
#
# running (0m11.1s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.1s/30s
#
# running (0m11.2s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.2s/30s
#
# running (0m11.3s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.3s/30s
#
# running (0m11.4s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.4s/30s
#
# running (0m11.5s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.5s/30s
#
# running (0m11.6s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.6s/30s
#
# running (0m11.7s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.7s/30s
#
# running (0m11.8s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [=============>------------------------] 1 VUs  11.8s/30s
#
# running (0m11.9s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  11.9s/30s
#
# running (0m12.0s), 1/1 VUs, 6 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.0s/30s
#
# running (0m12.1s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.1s/30s
#
# running (0m12.2s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.2s/30s
#
# running (0m12.3s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.3s/30s
#
# running (0m12.4s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.4s/30s
#
# running (0m12.5s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.5s/30s
#
# running (0m12.6s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [==============>-----------------------] 1 VUs  12.6s/30s
#
# running (0m12.7s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  12.7s/30s
#
# running (0m12.8s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  12.8s/30s
#
# running (0m12.9s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  12.9s/30s
#
# running (0m13.0s), 1/1 VUs, 7 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  13.0s/30s
#
# running (0m13.1s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  13.1s/30s
#
# running (0m13.2s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  13.2s/30s
#
# running (0m13.3s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  13.3s/30s
#
# running (0m13.4s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [===============>----------------------] 1 VUs  13.4s/30s
#
# running (0m13.5s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  13.5s/30s
#
# running (0m13.6s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  13.6s/30s
#
# running (0m13.7s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  13.7s/30s
#
# running (0m13.8s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  13.8s/30s
#
# running (0m13.9s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  13.9s/30s
#
# running (0m14.0s), 1/1 VUs, 8 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  14.0s/30s
#
# running (0m14.1s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  14.1s/30s
#
# running (0m14.2s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [================>---------------------] 1 VUs  14.2s/30s
#
# running (0m14.3s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.3s/30s
#
# running (0m14.4s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.4s/30s
#
# running (0m14.5s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.5s/30s
#
# running (0m14.6s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.6s/30s
#
# running (0m14.7s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.7s/30s
#
# running (0m14.8s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.8s/30s
#
# running (0m14.9s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  14.9s/30s
#
# running (0m15.0s), 1/1 VUs, 9 complete and 0 interrupted iterations
# default   [=================>--------------------] 1 VUs  15.0s/30s
#
# running (0m15.1s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.1s/30s
#
# running (0m15.2s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.2s/30s
#
# running (0m15.3s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.3s/30s
#
# running (0m15.4s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.4s/30s
#
# running (0m15.5s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.5s/30s
#
# running (0m15.6s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.6s/30s
#
# running (0m15.7s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [==================>-------------------] 1 VUs  15.7s/30s
#
# running (0m15.8s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  15.8s/30s
#
# running (0m15.9s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  15.9s/30s
#
# running (0m16.0s), 1/1 VUs, 10 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  16.0s/30s
#
# running (0m16.1s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  16.1s/30s
#
# running (0m16.2s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  16.2s/30s
#
# running (0m16.3s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  16.3s/30s
#
# running (0m16.4s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  16.4s/30s
#
# running (0m16.5s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [===================>------------------] 1 VUs  16.5s/30s
#
# running (0m16.6s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  16.6s/30s
#
# running (0m16.7s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  16.7s/30s
#
# running (0m16.8s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  16.8s/30s
#
# running (0m16.9s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  16.9s/30s
#
# running (0m17.0s), 1/1 VUs, 11 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  17.0s/30s
#
# running (0m17.1s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  17.1s/30s
#
# running (0m17.2s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  17.2s/30s
#
# running (0m17.3s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [====================>-----------------] 1 VUs  17.3s/30s
#
# running (0m17.4s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  17.4s/30s
#
# running (0m17.5s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  17.5s/30s
#
# running (0m17.6s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  17.6s/30s
#
# running (0m17.7s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  17.7s/30s
#
# running (0m17.8s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  17.8s/30s
#
# running (0m17.9s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  17.9s/30s
#
# running (0m18.0s), 1/1 VUs, 12 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  18.0s/30s
#
# running (0m18.1s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [=====================>----------------] 1 VUs  18.1s/30s
#
# running (0m18.2s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.2s/30s
#
# running (0m18.3s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.3s/30s
#
# running (0m18.4s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.4s/30s
#
# running (0m18.5s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.5s/30s
#
# running (0m18.6s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.6s/30s
#
# running (0m18.7s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.7s/30s
#
# running (0m18.8s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.8s/30s
#
# running (0m18.9s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [======================>---------------] 1 VUs  18.9s/30s
#
# running (0m19.0s), 1/1 VUs, 13 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.0s/30s
#
# running (0m19.1s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.1s/30s
#
# running (0m19.2s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.2s/30s
#
# running (0m19.3s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.3s/30s
#
# running (0m19.4s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.4s/30s
#
# running (0m19.5s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.5s/30s
#
# running (0m19.6s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.6s/30s
#
# running (0m19.7s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [=======================>--------------] 1 VUs  19.7s/30s
#
# running (0m19.8s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  19.8s/30s
#
# running (0m19.9s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  19.9s/30s
#
# running (0m20.0s), 1/1 VUs, 14 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  20.0s/30s
#
# running (0m20.1s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  20.1s/30s
#
# running (0m20.2s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  20.2s/30s
#
# running (0m20.3s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  20.3s/30s
#
# running (0m20.4s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  20.4s/30s
#
# running (0m20.5s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [========================>-------------] 1 VUs  20.5s/30s
#
# running (0m20.6s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  20.6s/30s
#
# running (0m20.7s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  20.7s/30s
#
# running (0m20.8s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  20.8s/30s
#
# running (0m20.9s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  20.9s/30s
#
# running (0m21.0s), 1/1 VUs, 15 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  21.0s/30s
#
# running (0m21.1s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  21.1s/30s
#
# running (0m21.2s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  21.2s/30s
#
# running (0m21.3s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [=========================>------------] 1 VUs  21.3s/30s
#
# running (0m21.4s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  21.4s/30s
#
# running (0m21.5s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  21.5s/30s
#
# running (0m21.6s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  21.6s/30s
#
# running (0m21.7s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  21.7s/30s
#
# running (0m21.8s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  21.8s/30s
#
# running (0m21.9s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  21.9s/30s
#
# running (0m22.0s), 1/1 VUs, 16 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  22.0s/30s
#
# running (0m22.1s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [==========================>-----------] 1 VUs  22.1s/30s
#
# running (0m22.2s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.2s/30s
#
# running (0m22.3s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.3s/30s
#
# running (0m22.4s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.4s/30s
#
# running (0m22.5s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.5s/30s
#
# running (0m22.6s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.6s/30s
#
# running (0m22.7s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.7s/30s
#
# running (0m22.8s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [===========================>----------] 1 VUs  22.8s/30s
#
# running (0m22.9s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  22.9s/30s
#
# running (0m23.0s), 1/1 VUs, 17 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.0s/30s
#
# running (0m23.1s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.1s/30s
#
# running (0m23.2s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.2s/30s
#
# running (0m23.3s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.3s/30s
#
# running (0m23.4s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.4s/30s
#
# running (0m23.5s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.5s/30s
#
# running (0m23.6s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [============================>---------] 1 VUs  23.6s/30s
#
# running (0m23.7s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  23.7s/30s
#
# running (0m23.8s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  23.8s/30s
#
# running (0m23.9s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  23.9s/30s
#
# running (0m24.0s), 1/1 VUs, 18 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  24.0s/30s
#
# running (0m24.1s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  24.1s/30s
#
# running (0m24.2s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  24.2s/30s
#
# running (0m24.3s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  24.3s/30s
#
# running (0m24.4s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [=============================>--------] 1 VUs  24.4s/30s
#
# running (0m24.5s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  24.5s/30s
#
# running (0m24.6s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  24.6s/30s
#
# running (0m24.7s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  24.7s/30s
#
# running (0m24.8s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  24.8s/30s
#
# running (0m24.9s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  24.9s/30s
#
# running (0m25.0s), 1/1 VUs, 19 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  25.0s/30s
#
# running (0m25.1s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  25.1s/30s
#
# running (0m25.2s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [==============================>-------] 1 VUs  25.2s/30s
#
# running (0m25.3s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.3s/30s
#
# running (0m25.4s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.4s/30s
#
# running (0m25.5s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.5s/30s
#
# running (0m25.6s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.6s/30s
#
# running (0m25.7s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.7s/30s
#
# running (0m25.8s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.8s/30s
#
# running (0m25.9s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  25.9s/30s
#
# running (0m26.0s), 1/1 VUs, 20 complete and 0 interrupted iterations
# default   [===============================>------] 1 VUs  26.0s/30s
#
# running (0m26.1s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.1s/30s
#
# running (0m26.2s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.2s/30s
#
# running (0m26.3s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.3s/30s
#
# running (0m26.4s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.4s/30s
#
# running (0m26.5s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.5s/30s
#
# running (0m26.6s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.6s/30s
#
# running (0m26.7s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.7s/30s
#
# running (0m26.8s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [================================>-----] 1 VUs  26.8s/30s
#
# running (0m26.9s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  26.9s/30s
#
# running (0m27.0s), 1/1 VUs, 21 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.0s/30s
#
# running (0m27.1s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.1s/30s
#
# running (0m27.2s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.2s/30s
#
# running (0m27.3s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.3s/30s
#
# running (0m27.4s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.4s/30s
#
# running (0m27.5s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.5s/30s
#
# running (0m27.6s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [=================================>----] 1 VUs  27.6s/30s
#
# running (0m27.7s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  27.7s/30s
#
# running (0m27.8s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  27.8s/30s
#
# running (0m27.9s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  27.9s/30s
#
# running (0m28.0s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  28.0s/30s
#
# running (0m28.1s), 1/1 VUs, 22 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  28.1s/30s
#
# running (0m28.2s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  28.2s/30s
#
# running (0m28.3s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  28.3s/30s
#
# running (0m28.4s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [==================================>---] 1 VUs  28.4s/30s
#
# running (0m28.5s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  28.5s/30s
#
# running (0m28.6s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  28.6s/30s
#
# running (0m28.7s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  28.7s/30s
#
# running (0m28.8s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  28.8s/30s
#
# running (0m28.9s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  28.9s/30s
#
# running (0m29.0s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  29.0s/30s
#
# running (0m29.1s), 1/1 VUs, 23 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  29.1s/30s
#
# running (0m29.2s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [===================================>--] 1 VUs  29.2s/30s
#
# running (0m29.3s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.3s/30s
#
# running (0m29.4s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.4s/30s
#
# running (0m29.5s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.5s/30s
#
# running (0m29.6s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.6s/30s
#
# running (0m29.7s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.7s/30s
#
# running (0m29.8s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.8s/30s
#
# running (0m29.9s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  29.9s/30s
#
# running (0m30.0s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default   [====================================>-] 1 VUs  30.0s/30s
#
# running (0m30.1s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default ↓ [======================================] 1 VUs  30s
#
#      data_received..................: 6.9 kB 228 B/s
#      data_sent......................: 2.2 kB 72 B/s
#      http_req_blocked...............: avg=373.9µs  min=8.15µs   med=11.14µs  max=9.08ms   p(90)=14.03µs  p(95)=15.09µs
#      http_req_connecting............: avg=349.28µs min=0s       med=0s       max=8.73ms   p(90)=0s       p(95)=0s
#      http_req_duration..............: avg=202.99ms min=4.26ms   med=5.06ms   max=4.53s    p(90)=73.39ms  p(95)=269.69ms
#        { expected_response:true }...: avg=202.99ms min=4.26ms   med=5.06ms   max=4.53s    p(90)=73.39ms  p(95)=269.69ms
#      http_req_failed................: 0.00%  ✓ 0       ✗ 25
#      http_req_receiving.............: avg=656.85µs min=120.62µs med=168.21µs max=11.08ms  p(90)=479.69µs p(95)=937.44µs
#      http_req_sending...............: avg=58.67µs  min=32.74µs  med=53.3µs   max=219.72µs p(90)=66.78µs  p(95)=95.22µs
#      http_req_tls_handshaking.......: avg=0s       min=0s       med=0s       max=0s       p(90)=0s       p(95)=0s
#      http_req_waiting...............: avg=202.27ms min=4.08ms   med=4.85ms   max=4.52s    p(90)=72.67ms  p(95)=268.9ms
#      http_reqs......................: 25     0.83031/s
#      iteration_duration.............: avg=1.2s     min=1s       med=1s       max=5.54s    p(90)=1.07s    p(95)=1.27s
#      iterations.....................: 25     0.83031/s
#      vus............................: 1      min=1     max=1
#      vus_max........................: 1      min=1     max=1
#
#
# running (0m30.1s), 1/1 VUs, 24 complete and 0 interrupted iterations
# default ↓ [======================================] 1 VUs  30s
#
# running (0m30.1s), 0/1 VUs, 25 complete and 0 interrupted iterations
# default ✓ [======================================] 1 VUs  30s
# Incorrect part for vus = 1: 0.0
#
#
#           /\      |‾‾| /‾‾/   /‾‾/
#      /\  /  \     |  |/  /   /  /
#     /  \/    \    |     (   /   ‾‾\
#    /          \   |  |\  \ |  (‾)  |
#   / __________ \  |__| \__\ \_____/ .io
#
#   execution: local
#      script: ../../grafana-k6/script.js
#      output: json (./out/out_2023-10-26_22-16-40/dotnet.json), csv (./out/out_2023-10-26_22-16-40/dotnet.csv)
#
#   scenarios: (100.00%) 1 scenario, 2 max VUs, 1m0s max duration (incl. graceful stop):
#            * default: 2 looping VUs for 30s (gracefulStop: 30s)
#
#
# running (0m00.1s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.1s/30s
#
# running (0m00.2s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.2s/30s
#
# running (0m00.3s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.3s/30s
#
# running (0m00.4s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.4s/30s
#
# running (0m00.5s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.5s/30s
#
# running (0m00.6s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.6s/30s
#
# running (0m00.7s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [--------------------------------------] 2 VUs  00.7s/30s
#
# running (0m00.8s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  00.8s/30s
#
# running (0m00.9s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  00.9s/30s
#
# running (0m01.0s), 2/2 VUs, 0 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  01.0s/30s
#
# running (0m01.1s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  01.1s/30s
#
# running (0m01.2s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  01.2s/30s
#
# running (0m01.3s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  01.3s/30s
#
# running (0m01.4s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  01.4s/30s
#
# running (0m01.5s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [>-------------------------------------] 2 VUs  01.5s/30s
#
# running (0m01.6s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  01.6s/30s
#
# running (0m01.7s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  01.7s/30s
#
# running (0m01.8s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  01.8s/30s
#
# running (0m01.9s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  01.9s/30s
#
# running (0m02.0s), 2/2 VUs, 2 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  02.0s/30s
#
# running (0m02.1s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  02.1s/30s
#
# running (0m02.2s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  02.2s/30s
#
# running (0m02.3s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [=>------------------------------------] 2 VUs  02.3s/30s
#
# running (0m02.4s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2 VUs  02.4s/30s
#
# running (0m02.5s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2 VUs  02.5s/30s
#
# running (0m02.6s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2 VUs  02.6s/30s
#
# running (0m02.7s), 2/2 VUs, 4 complete and 0 interrupted iterations
# default   [==>-----------------------------------] 2 VUs  02.7s/30s
#
# ...
#
# running (0m26.8s), 10239/10239 VUs, 27657 complete and 0 interrupted iterations
# default   [================================>-----] 10239 VUs  26.8s/30s
#
# running (0m26.9s), 10239/10239 VUs, 27924 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  26.9s/30s
#
# running (0m27.0s), 10239/10239 VUs, 28143 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.0s/30s
#
# running (0m27.1s), 10239/10239 VUs, 28420 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.1s/30s
#
# running (0m27.2s), 10239/10239 VUs, 28615 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.2s/30s
#
# running (0m27.3s), 10239/10239 VUs, 28771 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.3s/30s
#
# running (0m27.4s), 10239/10239 VUs, 28968 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.4s/30s
#
# running (0m27.5s), 10239/10239 VUs, 29192 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.5s/30s
#
# running (0m27.6s), 10239/10239 VUs, 29435 complete and 0 interrupted iterations
# default   [=================================>----] 10239 VUs  27.6s/30s
#
# running (0m27.7s), 10239/10239 VUs, 29674 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  27.7s/30s
#
# running (0m27.8s), 10239/10239 VUs, 29818 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  27.8s/30s
#
# running (0m27.9s), 10239/10239 VUs, 29996 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  27.9s/30s
#
# running (0m28.0s), 10239/10239 VUs, 30159 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  28.0s/30s
#
# running (0m28.1s), 10239/10239 VUs, 30332 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  28.1s/30s
#
# running (0m28.2s), 10239/10239 VUs, 30428 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  28.2s/30s
#
# running (0m28.3s), 10239/10239 VUs, 30606 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  28.3s/30s
#
# running (0m28.4s), 10239/10239 VUs, 30814 complete and 0 interrupted iterations
# default   [==================================>---] 10239 VUs  28.4s/30s
#
# running (0m28.5s), 10239/10239 VUs, 30956 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  28.5s/30s
#
# running (0m28.6s), 10239/10239 VUs, 31082 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  28.6s/30s
#
# running (0m28.7s), 10239/10239 VUs, 31207 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  28.7s/30s
#
# running (0m28.8s), 10239/10239 VUs, 31375 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  28.8s/30s
#
# running (0m28.9s), 10239/10239 VUs, 31529 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  28.9s/30s
#
# running (0m29.0s), 10239/10239 VUs, 31698 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  29.0s/30s
#
# running (0m29.1s), 10239/10239 VUs, 31917 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  29.1s/30s
#
# running (0m29.2s), 10239/10239 VUs, 32150 complete and 0 interrupted iterations
# default   [===================================>--] 10239 VUs  29.2s/30s
#
# running (0m29.3s), 10239/10239 VUs, 32382 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.3s/30s
#
# running (0m29.4s), 10239/10239 VUs, 32600 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.4s/30s
#
# running (0m29.5s), 10239/10239 VUs, 32804 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.5s/30s
#
# running (0m29.6s), 10239/10239 VUs, 32992 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.6s/30s
#
# running (0m29.7s), 10239/10239 VUs, 33240 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.7s/30s
#
# running (0m29.8s), 10239/10239 VUs, 33466 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.8s/30s
#
# running (0m29.9s), 10239/10239 VUs, 33633 complete and 0 interrupted iterations
# default   [====================================>-] 10239 VUs  29.9s/30s
#
# running (0m30.0s), 10232/10239 VUs, 33810 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.1s), 10044/10239 VUs, 33998 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.2s), 09864/10239 VUs, 34178 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.3s), 09754/10239 VUs, 34288 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.4s), 09632/10239 VUs, 34410 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.5s), 09512/10239 VUs, 34530 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.6s), 09414/10239 VUs, 34628 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.7s), 09346/10239 VUs, 34696 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.8s), 09243/10239 VUs, 34799 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m30.9s), 09185/10239 VUs, 34857 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.0s), 09089/10239 VUs, 34953 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.1s), 09011/10239 VUs, 35031 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.2s), 08953/10239 VUs, 35089 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.3s), 08894/10239 VUs, 35148 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.4s), 08727/10239 VUs, 35315 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.5s), 08475/10239 VUs, 35567 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.6s), 08229/10239 VUs, 35813 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.7s), 07920/10239 VUs, 36122 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.8s), 07667/10239 VUs, 36375 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m31.9s), 07475/10239 VUs, 36568 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.0s), 07103/10239 VUs, 36939 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.1s), 06825/10239 VUs, 37217 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.2s), 06674/10239 VUs, 37368 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.3s), 06446/10239 VUs, 37598 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.4s), 06228/10239 VUs, 37814 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.5s), 05740/10239 VUs, 38303 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.6s), 05461/10239 VUs, 38581 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.7s), 05143/10239 VUs, 38899 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.8s), 04877/10239 VUs, 39165 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m32.9s), 04694/10239 VUs, 39348 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.0s), 04462/10239 VUs, 39580 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.1s), 04333/10239 VUs, 39709 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.2s), 04126/10239 VUs, 39916 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.3s), 03921/10239 VUs, 40121 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.4s), 03761/10239 VUs, 40281 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.5s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.6s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.7s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.8s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m33.9s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.0s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.1s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.2s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.3s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.4s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.5s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.6s), 03703/10239 VUs, 40339 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.7s), 03506/10239 VUs, 40536 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.8s), 03183/10239 VUs, 40859 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m34.9s), 03034/10239 VUs, 41008 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.0s), 02778/10239 VUs, 41264 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.1s), 02462/10239 VUs, 41581 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.2s), 02166/10239 VUs, 41876 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.3s), 01939/10239 VUs, 42103 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.4s), 01574/10239 VUs, 42468 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.5s), 01286/10239 VUs, 42756 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.6s), 00990/10239 VUs, 43052 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.7s), 00702/10239 VUs, 43340 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.8s), 00386/10239 VUs, 43656 complete and 0 interrupted iterations
# default ↓ [======================================] 10239 VUs  30s
#
# running (0m35.9s), 00000/10239 VUs, 44042 complete and 0 interrupted iterations
# default ✓ [======================================] 10239 VUs  30s
#
# running (0m35.9s), 00000/10239 VUs, 44042 complete and 0 interrupted iterations
# default ✓ [======================================] 10239 VUs  30s
#
# running (0m35.9s), 00000/10239 VUs, 44042 complete and 0 interrupted iterations
# default ✓ [======================================] 10239 VUs  30s
#
# running (0m35.9s), 00000/10239 VUs, 44042 complete and 0 interrupted iterations
# default ✓ [======================================] 10239 VUs  30s
#
#      data_received..................: 12 MB  336 kB/s
#      data_sent......................: 3.8 MB 107 kB/s
#      http_req_blocked...............: avg=265.67ms min=3.74µs   med=7.12µs  max=4.49s    p(90)=904.77ms p(95)=3.02s
#      http_req_connecting............: avg=241.78ms min=0s       med=0s      max=3.71s    p(90)=648.4ms  p(95)=3.02s
#      http_req_duration..............: avg=5.74s    min=367.41ms med=4.76s   max=18.26s   p(90)=10.63s   p(95)=13.84s
#        { expected_response:true }...: avg=5.74s    min=367.41ms med=4.76s   max=18.26s   p(90)=10.63s   p(95)=13.84s
#      http_req_failed................: 0.00%  ✓ 0           ✗ 44042
#      http_req_receiving.............: avg=939.41µs min=44.92µs  med=77.6µs  max=1.23s    p(90)=145.41µs p(95)=460.51µs
#      http_req_sending...............: avg=8.05ms   min=17.3µs   med=31.96µs max=932.54ms p(90)=21.32ms  p(95)=53.24ms
#      http_req_tls_handshaking.......: avg=0s       min=0s       med=0s      max=0s       p(90)=0s       p(95)=0s
#      http_req_waiting...............: avg=5.73s    min=366.54ms med=4.76s   max=18.24s   p(90)=10.57s   p(95)=13.84s
#      http_reqs......................: 44042  1227.055014/s
#      iteration_duration.............: avg=7.02s    min=1.36s    med=5.78s   max=19.93s   p(90)=13.81s   p(95)=16.13s
#      iterations.....................: 44042  1227.055014/s
#      vus............................: 2844   min=0         max=10239
#      vus_max........................: 10239  min=3313      max=10239
#
#
# running (0m35.9s), 00000/10239 VUs, 44042 complete and 0 interrupted iterations
# default ✓ [======================================] 10239 VUs  30s
#
# running (0m35.9s), 00000/10239 VUs, 44042 complete and 0 interrupted iterations
# default ✓ [======================================] 10239 VUs  30s
# Incorrect part for vus = 10239: 0.0

# %% [markdown]
# ## Smoke Processing data

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import sys
# setting path
sys.path.append('../common')
import utils


dir = utils.get_last_result_dir(setup_data=data)
print(dir)
path = f'.{data["test_result_base_dir"]}/{dir}/django.json'
print(path)
df = pd.read_csv(f'{dir}/django.csv')
# Out:
# out/out_2023-10-14_14-53-04
# .out/out/out_2023-10-14_14-53-04/django.json

# %%
path = f'./{dir}/{data["app"]["name"]}.csv'
df = pd.read_csv(path)
# Out:
# 0.0

# %%
df.head()
# Out:
#                 metric_name   timestamp  metric_value  check  error  \
# 0                 http_reqs  1697287988      1.000000    NaN    NaN
# 1         http_req_duration  1697287988     21.824395    NaN    NaN
# 2          http_req_blocked  1697287988      0.585770    NaN    NaN
# 3       http_req_connecting  1697287988      0.313478    NaN    NaN
# 4  http_req_tls_handshaking  1697287988      0.000000    NaN    NaN
#
#    error_code expected_response  group method  \
# 0         NaN              True    NaN    GET
# 1         NaN              True    NaN    GET
# 2         NaN              True    NaN    GET
# 3         NaN              True    NaN    GET
# 4         NaN              True    NaN    GET
#
#                                 name     proto scenario  service  status  \
# 0  http://localhost:8000/collisions/  HTTP/1.1  default      NaN   200.0
# 1  http://localhost:8000/collisions/  HTTP/1.1  default      NaN   200.0
# 2  http://localhost:8000/collisions/  HTTP/1.1  default      NaN   200.0
# 3  http://localhost:8000/collisions/  HTTP/1.1  default      NaN   200.0
# 4  http://localhost:8000/collisions/  HTTP/1.1  default      NaN   200.0
#
#    subproto  tls_version                                url  extra_tags  \
# 0       NaN          NaN  http://localhost:8000/collisions/         NaN
# 1       NaN          NaN  http://localhost:8000/collisions/         NaN
# 2       NaN          NaN  http://localhost:8000/collisions/         NaN
# 3       NaN          NaN  http://localhost:8000/collisions/         NaN
# 4       NaN          NaN  http://localhost:8000/collisions/         NaN
#
#    metadata
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   metric_name        450 non-null    object
#  1   timestamp          450 non-null    int64
#  2   metric_value       450 non-null    float64
#  3   check              0 non-null      float64
#  4   error              0 non-null      float64
#  5   error_code         0 non-null      float64
#  6   expected_response  270 non-null    object
#  7   group              0 non-null      float64
#  8   method             270 non-null    object
#  9   name               270 non-null    object
#  10  proto              270 non-null    object
#  11  scenario           390 non-null    object
#  12  service            0 non-null      float64
#  13  status             270 non-null    float64
#  14  subproto           0 non-null      float64
#  15  tls_version        0 non-null      float64
#  16  url                270 non-null    object
#  17  extra_tags         0 non-null      float64
#  18  metadata           0 non-null      float64
# dtypes: float64(11), int64(1), object(7)
# memory usage: 66.9+ KB

# %%
df['metric_name'].unique()
# Out:
# array(['http_reqs', 'http_req_duration', 'http_req_blocked',
#        'http_req_connecting', 'http_req_tls_handshaking',
#        'http_req_sending', 'http_req_waiting', 'http_req_receiving',
#        'http_req_failed', 'vus', 'vus_max', 'data_sent', 'data_received',
#        'iteration_duration', 'iterations'], dtype=object)

# %%
chart = sns.countplot(data=df, x='metric_name')
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
chart.bar_label(chart.containers[0])
# Out:
# [Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30'),
#  Text(0, 0, '30')]

# %%
df.shape
# Out:
# (450, 19)

# %%
df_1 = df.loc[(df['metric_name'] == 'http_req_duration')]
df_1.shape
# Out:
# (30, 19)

# %%
df_1.head()
# Out:
#         metric_name   timestamp  metric_value  check  error  error_code  \
# 8   http_req_failed  1697287988           0.0    NaN    NaN         NaN
# 23  http_req_failed  1697287989           0.0    NaN    NaN         NaN
# 38  http_req_failed  1697287990           0.0    NaN    NaN         NaN
# 53  http_req_failed  1697287991           0.0    NaN    NaN         NaN
# 68  http_req_failed  1697287992           0.0    NaN    NaN         NaN
#
#    expected_response  group method                               name  \
# 8               True    NaN    GET  http://localhost:8000/collisions/
# 23              True    NaN    GET  http://localhost:8000/collisions/
# 38              True    NaN    GET  http://localhost:8000/collisions/
# 53              True    NaN    GET  http://localhost:8000/collisions/
# 68              True    NaN    GET  http://localhost:8000/collisions/
#
#        proto scenario  service  status  subproto  tls_version  \
# 8   HTTP/1.1  default      NaN   200.0       NaN          NaN
# 23  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 38  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 53  HTTP/1.1  default      NaN   200.0       NaN          NaN
# 68  HTTP/1.1  default      NaN   200.0       NaN          NaN
#
#                                   url  extra_tags  metadata
# 8   http://localhost:8000/collisions/         NaN       NaN
# 23  http://localhost:8000/collisions/         NaN       NaN
# 38  http://localhost:8000/collisions/         NaN       NaN
# 53  http://localhost:8000/collisions/         NaN       NaN
# 68  http://localhost:8000/collisions/         NaN       NaN
